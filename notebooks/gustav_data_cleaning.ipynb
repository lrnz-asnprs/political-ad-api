# %% [markdown]
# # Basic setup for fetching data from the facebook api
#
# ### Remember to add an active access token below and adjust the parameters and fields if necessary

# %%
# must be specified to be able to use methods of package
import sys
sys.path.append('../src') 
# import packages
from political_ads.helper import *
import pandas as pd
from political_ads.api_request import API_request
from political_ads.Preprocessor import *

# %%
# # insert your access token here (expires every 2 hours)
# access_token = ""
# # get_new_access_token: https://developers.facebook.com/tools/explorer/


# #https://www.facebook.com/ads/library/report
# # "../data/generated_dataset.txt",

# # PARAMETERS NECESSARY
# ad_type = "POLITICAL_AND_ISSUE_ADS"
# ad_reached_countries = ['US'] # Facebook delivered the ads in these countries. Provided as ISO country codes.
# search_terms = "Joe Biden" # The terms to search for in your query. We treat a blank space as a logical AND and search for both terms and no other operators. The limit of your string is 100 characters or less.
# limit = 1700
# start_date = "2020-08-00"
# end_date = "2020-11-03"

# # FIELDS to specify your results
# fields = ["id", "page_name", "ad_creative_body", "impressions", "delivery_by_region", "demographic_distribution", "ad_delivery_start_time", "bylines", "spend"]

# # see here for more parameters and fields: https://www.facebook.com/ads/library/api/?source=archive-landing-page 

# input_url = f"https://graph.facebook.com/v12.0/ads_archive?search_terms={search_terms}&ad_type={ad_type}&ad_reached_countries={ad_reached_countries}&fields={fields}&limit={limit}&ad_delivery_date_min={start_date}&ad_delivery_date_max={end_date}"

# api = API_request()

# response = api.get_json_response(input_url, access_token)

# data = pd.DataFrame(response["data"])

# %%
# import time 

# #https://developers.facebook.com/docs/graph-api/results

# iterations = 10
# sleep_time_sec = 10

# counter = 0

# for i in range(10):

#     paging = response["paging"]["next"]
#     next_response = get_json_response(paging, access_token)

#     new_page = pd.DataFrame(next_response['data'])
#     data = data.append(new_page, ignore_index=True)
#     time.sleep(10)
#     counter+=1
#     print(counter)

# %% [markdown]
# # Looking at the data-set with all the politicians
#
# ## Making aggregate methods from their target groups (Demographic DATA)

# %%
#Code to read from our full dataset:
preprocess = Preprocessor()
df = preprocess.file_to_df('/home/gustavgyrst/Desktop/Research Project/political-ad-api/data/all_politicians_aggregated.txt')

# %%
df['demographic_distribution'].iloc[0]
df.dropna(inplace=True) #

# %%
# data.drop(['age_distribution', 'gender'], axis=1)

#data['age_distribution'] = data['demographic_distribution'].apply(lambda x: get_age_distribution(x, all_ages=True))

demographic_data = df[['page_name', 'demographic_distribution']].reset_index().drop(columns='index')

# %% [markdown]
# # Finding the Missing Page_names

# %%
df_missing = pd.read_csv('/home/gustavgyrst/Desktop/Research Project/political-ad-api/src/data_sets/missing_pid.csv')
df_all_ad_pages = pd.read_csv('/home/gustavgyrst/Desktop/Research Project/political-ad-api/data/FacebookAdLibraryReport_2021-10-15_US_lifelong_advertisers.csv')
# Out:
# /home/gustavgyrst/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_all_ad_pages[df_all_ad_pages['Page Name'].str.contains('Vicente Gonzalez', na=False)].head(50)
# Out:
#                  Page ID                               Page Name  \
# 13616    206690159663661  U.S. Congressman Vicente Gonzalez 2022
# 30729    206690159663661  U.S. Congressman Vicente Gonzalez 2022
# 48586   1838012813083658            Congressman Vicente Gonzalez
# 60721   1838012813083658            Congressman Vicente Gonzalez
# 90177   1838012813083658            Congressman Vicente Gonzalez
# 168447   206690159663661  U.S. Congressman Vicente Gonzalez 2022
# 223284   206690159663661  U.S. Congressman Vicente Gonzalez 2022
#
#                                           Disclaimer Amount Spent (USD)  \
# 13616                  VICENTE GONZALEZ FOR CONGRESS              15688
# 30729        Vicente Gonzalez for Congress Committee               4030
# 48586                   Congressman Vicente Gonzalez               1696
# 60721             These ads ran without a disclaimer               1050
# 90177                   Congressman Vicente Gonzalez                420
# 168447  Vicente Gonzalez for U.S. Congress Committee               ≤100
# 223284            These ads ran without a disclaimer               ≤100
#
#         Number of Ads in Library
# 13616                        292
# 30729                        173
# 48586                          4
# 60721                          4
# 90177                          2
# 168447                         9
# 223284                         6

# %%
df_missing[df_missing.page_id == 'no match'].count()
# Out:
# Unnamed: 0         166
# first_name         166
# last_name          166
# full_name          166
# type               166
# state              166
# district           136
# party              166
# facebook           132
# page_name           67
# identifier         166
# page_id            166
# already_fetched    166
# dtype: int64

# %%
#Filtering with two values with a regex AND operation (e.g., first name "Bernie" AND "Sanders" will return all results that contain both Bernie and Sanders)
def get_page_id(data: pd.DataFrame, first_name: str, last_name:str):
    match = data[data["Page Name"].str.contains(r'^(?=.*'+first_name+')(?=.*'+last_name+')', na=False)]
    if len(match) != 0:
        return match.iloc[0][0]
    else:
        return "no match"

# %%
#Testing Regex filtering:
f = 'Bernie'
l = 'Sanders'
match = df_all_ad_pages[df_all_ad_pages["Page Name"].str.contains(r'^(?=.*'+f+')(?=.*'+l+')', na=False)]
match
# Out:
#                  Page ID                              Page Name  \
# 26       124955570892789                         Bernie Sanders
# 77       124955570892789                         Bernie Sanders
# 1443     124955570892789                         Bernie Sanders
# 14317   1645816202305254          The People For Bernie Sanders
# 44528    107229050703874                Bernie Sanders Fan Club
# ...                  ...                                    ...
# 352660   799023333537673             Denmark for Bernie Sanders
# 368255   427298174139138     Sedgwick County for Bernie Sanders
# 372910   142457072843777         Rogers Park For Bernie Sanders
# 373310   158942027817875  Filipino Americans for Bernie Sanders
# 381564  1672284073041311                      US Bernie Sanders
#
#                                 Disclaimer Amount Spent (USD)  \
# 26                             BERNIE 2020            9199592
# 77                            Bernie 2020.            4132342
# 1443             Friends of Bernie Sanders             274572
# 14317            Paid for by Be a Hero PAC              14463
# 44528                        Imran M Jemal               2006
# ...                                    ...                ...
# 352660  These ads ran without a disclaimer               ≤100
# 368255  These ads ran without a disclaimer               ≤100
# 372910  These ads ran without a disclaimer               ≤100
# 373310  These ads ran without a disclaimer               ≤100
# 381564  These ads ran without a disclaimer               ≤100
#
#         Number of Ads in Library
# 26                         23830
# 77                         45749
# 1443                         825
# 14317                        120
# 44528                        175
# ...                          ...
# 352660                         2
# 368255                         1
# 372910                         1
# 373310                         1
# 381564                         1
#
# [86 rows x 5 columns]

# %%
#Extracting the data to the df with all the fetched new page_ids
df_missing["page_id"] = df_missing.apply(lambda x: get_page_id(df_all_ad_pages, first_name=x['first_name'], last_name=x['last_name']),axis=1)

# %%
#Filtering by just one value
def get_page_id1(data: pd.DataFrame, name: str):
    
    match = data[data["Page Name"].str.contains(name, na=False)]
    if len(match) != 0:
        return match.iloc[0][0]
    else:
        return "no match"

# %%
#Now Cleaning the remaining with only last-name match/search
df_missing['page_id'] = df_missing.apply(lambda x: get_page_id1(df_all_ad_pages, name=x['last_name']) if x['page_id'] == 'no match' else x['page_id'], axis=1)

# %%
print(df_missing[df_missing.page_id == 'no match'].count()[0]) #value of no matches left
len(df_missing) #total length
# Out:
# 7
# 181

# %% [markdown]
# # Quality Control and Cleaning Faulty Values

# %%
def quality_control_page_id(df, df_transparency_report):
    df_without_no_match = df[df.page_id != 'no match']
    for id in df_without_no_match.page_id:
        df_temp = df_transparency_report[df_transparency_report['Page ID'] == id]
        print("Page name transparency report: " + df_temp['Page Name'].unique())
        df_temp2 = df_without_no_match[df_without_no_match['page_id'] == id]
        print("Missing list: df_temp2: "  + df_temp2['full_name'])

# %%
#Template for the filtering method

#find the replacement value in the transparency report - looked up with parsing the correct facebook page name
replacement = df_all_ad_pages[df_all_ad_pages['Page Name'] == 'Bob Menendez']['Page ID'].iloc[0] #Have to add the iloc[0] to only get the specific value and the whole data series
row_index = df_missing[df_missing['full_name'] == 'Robert Menendez'].page_id.index[0]

type(replacement)
replacement

#column number for page_id
df_missing.columns[11]
df_missing.iat[row_index, 11] = replacement

row_index
# Out:
# 4

# %%
def replace_false_pages(dict, df_missing, df_transparency_report):
    for key, value in dict.items():
        print(key, value)
        row_index = df_missing[df_missing['full_name'] == key].page_id.index[0]    
        print(row_index)
        if value == 'no ad account':
            replacement = 'no ad account'
        else:
            replacement = df_transparency_report[df_transparency_report['Page Name'] == value]['Page ID'].iloc[0] #Have to add the iloc[0] to only get the specific value and the whole data series
        
        df_missing.iat[row_index, 11] = replacement

# %%
# Out:
# Henry C. "Hank" Johnson, Jr.Congressman Hank Johnson
# John H. RutherfordNo Ad Account
# Robert MenendezBob Menendez

# %%
#Finding the faulty fetches:
dict_of_faulty_pid = {
        'Henry C. "Hank" Johnson, Jr.': 'Congressman Hank Johnson',
        'John H. Rutherford':'no ad account',
        'Robert Menendez': 'Bob Menendez',
        'Benjamin L. Cardin': 'no ad account',
        'H. Morgan Griffith': 'Morgan Griffith for Congress',
        'Eddie Bernice Johnson': 'no ad account',
        'Gregory W. Meeks': 'no ad account',
        'Jerry Moran':'no ad account',
        'Harold Rogers':'Hal Rogers',
        'Donald M. Payne, Jr.': 'no ad account',
        'Robin L. Kelly': 'no ad account',
        'Donald S. Beyer, Jr.': 'no ad account',
        'J. Luis Correa':'Rep. Lou Correa',
        'A. Drew Ferguson IV':'Congressman Drew Ferguson',
        'W. Gregory Steube':'Congressman Greg Steube',
        'C. Scott Franklin':'Congressman Scott Franklin',
        'Bradley Scott Schneider':'Congressman Brad Schneider',
        'Scott DesJarlais': 'no ad account',
        'Tom O’Halleran':'Rep. Tom O\'Halleran',
        'Louie Gohmert': 'no ad account',
        'John Hoeven':'no ad account',
        'Lisa Murkowski':'no ad account',
        'Aumua Amata Coleman Radewagen':'no ad account',
        'Jenniffer González-Colón':'no ad account'
        }

# %% [markdown]
# ## Documentation of filtering process:
#
# The page_ids for the ad campaign pages of the politicians are not accessible anywhere publically. Therefore, we have used the transparency report of all ad pages to fetch the page ids of the US Congress members. This is done in three steps. First we filter by "Full_name". This was highly efficient as most politicians used their full name for their page name.
#
# The second phase of filtering then occuring by a regex statement with first and last name. This gets us down only missing 66 politicians.
#
# For the last 66 polticians we use the lastname alone for the filtering.
#
#
# There are several cases when we have tried to filter out pages that it resulted in a false data_set, some examples are presented below.
# I had to go through full set of 180 manually to filter these cases out and clean the data. This was gone by cross checking and finding their facebook page, then trying to find their facebook account in the transparency report (both in the dataframe version and the website interactive page)
#
# ### Examples:
#
# ["Page name transparency report: Mark Amodei Isn't Fighting for Us"]
# 88    Missing list: df_temp2: Mark E. Amodei
#
# ['Page name transparency report: Sharon Whitehurst-Payne for San Diego School Board']
# 90    Missing list: df_temp2: Donald M. Payne, Jr.
#
# ['Page name transparency report: Captain Mark Kelly']
# 102    Missing list: df_temp2: Robin L. Kelly
#
# While Robin Kelly has a facebook account with many followers, she does not have an ad account.
# https://www.facebook.com/reprobinkelly
#
# ['Page name transparency report: Jay Schneiderman for Southampton Town Supervisor']
# 123    Missing list: df_temp2: Bradley Scott Schneider
#
#
# ['Page name transparency report: Help Bring Justice To Robert D. Correale, Esq., his former law firm, Maynard & Truland']
# 127    Missing list: df_temp2: J. Luis Correa
#
# These have been cleaned out by going through the dataset manually.
#
# ### Could be good to add multiple pages for some of them? Or at least we have mention this in our limitations
# additional - extra pages for politicians:
# Drew Ferguson
# Greg Steube
#
# ### all polticians have facebook pages not all have ad accounts
#
# --> a lot have multiple pages (both 'senator bob connison' and 'bob connison')

# %%
replace_false_pages(dict_of_faulty_pid, df_missing, df_all_ad_pages)
# Out:
# Henry C. "Hank" Johnson, Jr. Congressman Hank Johnson
# 41
# John H. Rutherford no ad account
# 129
# Robert Menendez Bob Menendez
# 4
# Benjamin L. Cardin no ad account
# 1
# H. Morgan Griffith Morgan Griffith for Congress
# 34
# Eddie Bernice Johnson no ad account
# 40
# Gregory W. Meeks no ad account
# 54
# Jerry Moran no ad account
# 55
# Harold Rogers Hal Rogers
# 66
# Donald M. Payne, Jr. no ad account
# 90
# Robin L. Kelly no ad account
# 102
# Donald S. Beyer, Jr. no ad account
# 117
# J. Luis Correa Rep. Lou Correa
# 127
# A. Drew Ferguson IV Congressman Drew Ferguson
# 134
# W. Gregory Steube Congressman Greg Steube
# 142
# C. Scott Franklin Congressman Scott Franklin
# 166
# Bradley Scott Schneider Congressman Brad Schneider
# 123
# Scott DesJarlais no ad account
# 27
# Tom O’Halleran Rep. Tom O'Halleran
# 124
# Louie Gohmert no ad account
# 32
# John Hoeven no ad account
# 38
# Lisa Murkowski no ad account
# 56
# Aumua Amata Coleman Radewagen no ad account
# 121
# Jenniffer González-Colón no ad account
# 138

# %%
df_all_ad_pages[df_all_ad_pages['Page Name'].str.contains('Maria Cantwell', na=False)].head(20)
# Out:
#          Page ID       Page Name        Disclaimer Amount Spent (USD)  \
# 1395  9351652533  Maria Cantwell  Friends of Maria             284524
#
#       Number of Ads in Library
# 1395                       102

# %%
df_missing[df_missing.page_id.str.contains("no match", na=False)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, first_name, last_name, full_name, type, state, district, party, facebook, page_name, identifier, page_id, already_fetched]
# Index: []

# %%
#df_missing.to_csv(path_or_buf='/home/gustavgyrst/Desktop/Research Project/political-ad-api/src/data_sets/found_missing_pid.csv')
# Out:
#                  Page ID                 Page Name  \
# 2146    1374601146109275  French Hill for Arkansas
# 12767    727280547367245   Congressman French Hill
# 23844   1374601146109275  French Hill for Arkansas
# 25976    727280547367245   Congressman French Hill
# 31694   1374601146109275  French Hill for Arkansas
# 75033    727280547367245   Congressman French Hill
# 188507   727280547367245   Congressman French Hill
#
#                                 Disclaimer Amount Spent (USD)  \
# 2146              French Hill for Arkansas             182343
# 12767              Congressman French Hill              17270
# 23844   These ads ran without a disclaimer               6318
# 25976    Office of Congressman French Hill               5437
# 31694             FRENCH HILL FOR ARKANSAS               3828
# 75033           Representative French Hill                654
# 188507  These ads ran without a disclaimer               ≤100
#
#         Number of Ads in Library
# 2146                         595
# 12767                         78
# 23844                          6
# 25976                         85
# 31694                         27
# 75033                          5
# 188507                         1

# %%
df_all_ad_pages[df_all_ad_pages['Page Name'].str.contains('Claudia Tenney', na=False)].head(50)
# Out:
#                 Page ID                                          Page Name  \
# 3306   2220944231249057                        Claudia Tenney Wrong for NY
# 4675    464292670410321                        Claudia Tenney for Congress
# 7313    100910491745994  Claudia Tenney: In the pocket of corporate spe...
# 11788   183020072173458                                Rep. Claudia Tenney
# 28843   464292670410321                        Claudia Tenney for Congress
# 53500  1961305130853062               Claudia Tenney's Healthcare Disaster
# 64551  1961305130853062               Claudia Tenney's Healthcare Disaster
#
#                                               Disclaimer Amount Spent (USD)  \
# 3306   DCCC. 430 South Capitol St, S.E. Washington, D...             107390
# 4675                                 TENNEY FOR CONGRESS              69277
# 7313                                                DCCC              38064
# 11788             Office of Congresswoman Claudia Tenney              19371
# 28843                        Claudia Tenney for Congress               4510
# 53500                 These ads ran without a disclaimer               1388
# 64551                                 House Majority PAC                926
#
#        Number of Ads in Library
# 3306                         50
# 4675                        184
# 7313                         38
# 11788                        57
# 28843                        32
# 53500                        26
# 64551                        31

# %%
df_pol = pd.read_csv('/home/gustavgyrst/Desktop/Research Project/political-ad-api/src/data_sets/legislators_fb_info.csv')

# %%
df_for_quality_control = df_pol[df_pol.already_fetched == 'done']

df_for_quality_control[df_for_quality_control.full_name == 'John Kennedy']
# Out:
#      Unnamed: 0 first_name last_name     full_name type state  district  \
# 322         322       John   Kennedy  John Kennedy  sen    LA       NaN
#
#           party              facebook page_name  identifier          page_id  \
# 322  Republican  JohnKennedyLouisiana       NaN           0  491347857894708
#
#     already_fetched
# 322            done

# %%
df_without_no_match = df_for_quality_control[df_for_quality_control.page_id != 'no match']
for id in df_without_no_match.page_id:
    id = int(id)
    df_temp = df_all_ad_pages[df_all_ad_pages['Page ID'] == id]
    print("Page name transparency report: " + df_temp['Page Name'].unique())
    df_temp2 = df_without_no_match[df_without_no_match['page_id'] == str(id)]
    print("Missing list: df_temp2: "  + df_temp2['full_name'])
# Out:
# ['Page name transparency report: Sherrod Brown']
# 0    Missing list: df_temp2: Sherrod Brown
# Name: full_name, dtype: object
# ['Page name transparency report: Dianne Feinstein']
# 5    Missing list: df_temp2: Dianne Feinstein
# Name: full_name, dtype: object
# ['Page name transparency report: Amy Klobuchar']
# 6    Missing list: df_temp2: Amy Klobuchar
# Name: full_name, dtype: object
# ['Page name transparency report: Debbie Stabenow']
# 9    Missing list: df_temp2: Debbie Stabenow
# Name: full_name, dtype: object
# ['Page name transparency report: Jon Tester']
# 10    Missing list: df_temp2: Jon Tester
# Name: full_name, dtype: object
# ['Page name transparency report: Sheldon Whitehouse']
# 11    Missing list: df_temp2: Sheldon Whitehouse
# Name: full_name, dtype: object
# ['Page name transparency report: John Barrasso']
# 12    Missing list: df_temp2: John Barrasso
# Name: full_name, dtype: object
# ['Page name transparency report: John Cornyn']
# 15    Missing list: df_temp2: John Cornyn
# Name: full_name, dtype: object
# ['Page name transparency report: Lindsey Graham']
# 17    Missing list: df_temp2: Lindsey Graham
# Name: full_name, dtype: object
# ['Page name transparency report: Mitch McConnell']
# 19    Missing list: df_temp2: Mitch McConnell
# Name: full_name, dtype: object
# ['Page name transparency report: Jeff Merkley']
# 20    Missing list: df_temp2: Jeff Merkley
# Name: full_name, dtype: object
# ['Page name transparency report: Jack Reed']
# 21    Missing list: df_temp2: Jack Reed
# Name: full_name, dtype: object
# ['Page name transparency report: Jeanne Shaheen']
# 23    Missing list: df_temp2: Jeanne Shaheen
# Name: full_name, dtype: object
# ['Page name transparency report: Tammy Baldwin']
# 29    Missing list: df_temp2: Tammy Baldwin
# Name: full_name, dtype: object
# ['Page name transparency report: Karen Bass']
# 30    Missing list: df_temp2: Karen Bass
# Name: full_name, dtype: object
# ['Page name transparency report: Marsha Blackburn']
# 34    Missing list: df_temp2: Marsha Blackburn
# Name: full_name, dtype: object
# ['Page name transparency report: Earl Blumenauer']
# 35    Missing list: df_temp2: Earl Blumenauer
# Name: full_name, dtype: object
# ['Page name transparency report: Richard Blumenthal']
# 36    Missing list: df_temp2: Richard Blumenthal
# Name: full_name, dtype: object
# ['Page name transparency report: Roy Blunt']
# 37    Missing list: df_temp2: Roy Blunt
# Name: full_name, dtype: object
# ['Page name transparency report: John Boozman']
# 38    Missing list: df_temp2: John Boozman
# Name: full_name, dtype: object
# ['Page name transparency report: Kevin Brady for Congress']
# 39    Missing list: df_temp2: Kevin Brady
# Name: full_name, dtype: object
# ['Page name transparency report: Mo Brooks']
# 40    Missing list: df_temp2: Mo Brooks
# Name: full_name, dtype: object
# ['Page name transparency report: Vern Buchanan']
# 41    Missing list: df_temp2: Vern Buchanan
# Name: full_name, dtype: object
# ['Page name transparency report: Larry Bucshon']
# 42    Missing list: df_temp2: Larry Bucshon
# Name: full_name, dtype: object
# ['Page name transparency report: Richard Burroughs']
# 44    Missing list: df_temp2: Richard Burr
# Name: full_name, dtype: object
# ['Page name transparency report: G. K. Butterfield for Congress']
# 45    Missing list: df_temp2: G. K. Butterfield
# Name: full_name, dtype: object
# ['Page name transparency report: Ken Calvert']
# 46    Missing list: df_temp2: Ken Calvert
# Name: full_name, dtype: object
# ['Page name transparency report: Shelley Moore Capito']
# 47    Missing list: df_temp2: Shelley Moore Capito
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman André Carson']
# 48    Missing list: df_temp2: André Carson
# Name: full_name, dtype: object
# ['Page name transparency report: Bill Cassidy']
# 50    Missing list: df_temp2: Bill Cassidy
# Name: full_name, dtype: object
# ['Page name transparency report: Shady Steve Chabot']
# 52    Missing list: df_temp2: Steve Chabot
# Name: full_name, dtype: object
# ['Page name transparency report: Judy Chu']
# 53    Missing list: df_temp2: Judy Chu
# Name: full_name, dtype: object
# ['Page name transparency report: David N. Cicilline']
# 54    Missing list: df_temp2: David N. Cicilline
# Name: full_name, dtype: object
# ['Page name transparency report: Yvette D. Clarke']
# 55    Missing list: df_temp2: Yvette D. Clarke
# Name: full_name, dtype: object
# ['Page name transparency report: Emanuel Cleaver II']
# 56    Missing list: df_temp2: Emanuel Cleaver
# Name: full_name, dtype: object
# ['Page name transparency report: James E. Clyburn']
# 57    Missing list: df_temp2: James E. Clyburn
# Name: full_name, dtype: object
# ['Page name transparency report: Steve Cohen']
# 58    Missing list: df_temp2: Steve Cohen
# Name: full_name, dtype: object
# ['Page name transparency report: Tom Cole']
# 59    Missing list: df_temp2: Tom Cole
# Name: full_name, dtype: object
# ['Page name transparency report: Jim Cooper for Congress']
# 61    Missing list: df_temp2: Jim Cooper
# Name: full_name, dtype: object
# ['Page name transparency report: Jim Costa for Congress']
# 62    Missing list: df_temp2: Jim Costa
# Name: full_name, dtype: object
# ['Page name transparency report: Joe Courtney for Congress']
# 63    Missing list: df_temp2: Joe Courtney
# Name: full_name, dtype: object
# ['Page name transparency report: Henry Cuellar']
# 66    Missing list: df_temp2: Henry Cuellar
# Name: full_name, dtype: object
# ['Page name transparency report: Danny K. Davis']
# 67    Missing list: df_temp2: Danny K. Davis
# Name: full_name, dtype: object
# ['Page name transparency report: Diana DeGette']
# 69    Missing list: df_temp2: Diana DeGette
# Name: full_name, dtype: object
# ['Page name transparency report: Mario Diaz-Balart']
# 73    Missing list: df_temp2: Mario Diaz-Balart
# Name: full_name, dtype: object
# ['Page name transparency report: Lloyd Doggett']
# 74    Missing list: df_temp2: Lloyd Doggett
# Name: full_name, dtype: object
# ['Page name transparency report: Jeff Duncan']
# 76    Missing list: df_temp2: Jeff Duncan
# Name: full_name, dtype: object
# ['Page name transparency report: Jeff Fortenberry']
# 79    Missing list: df_temp2: Jeff Fortenberry
# Name: full_name, dtype: object
# ['Page name transparency report: Virginia Foxx for Congress']
# 80    Missing list: df_temp2: Virginia Foxx
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman John Garamendi']
# 81    Missing list: df_temp2: John Garamendi
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman Bob Gibbs']
# 82    Missing list: df_temp2: Bob Gibbs
# Name: full_name, dtype: object
# ['Page name transparency report: Kay Granger Campaign']
# 85    Missing list: df_temp2: Kay Granger
# Name: full_name, dtype: object
# ['Page name transparency report: Chuck Grassley']
# 86    Missing list: df_temp2: Chuck Grassley
# Name: full_name, dtype: object
# ['Page name transparency report: Sam Graves for Congress']
# 87    Missing list: df_temp2: Sam Graves
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman Al Green']
# 88    Missing list: df_temp2: Al Green
# Name: full_name, dtype: object
# ['Page name transparency report: Brett Guthrie']
# 91    Missing list: df_temp2: Brett Guthrie
# Name: full_name, dtype: object
# ['Page name transparency report: Andy Harris']
# 92    Missing list: df_temp2: Andy Harris
# Name: full_name, dtype: object
# ['Page name transparency report: Vicky Hartzler']
# 93    Missing list: df_temp2: Vicky Hartzler
# Name: full_name, dtype: object
# ['Page name transparency report: Martin Heinrich']
# 94    Missing list: df_temp2: Martin Heinrich
# Name: full_name, dtype: object
# ['Page name transparency report: Jaime Herrera Beutler']
# 95    Missing list: df_temp2: Jaime Herrera Beutler
# Name: full_name, dtype: object
# ['Page name transparency report: Brian Higgins']
# 96    Missing list: df_temp2: Brian Higgins
# Name: full_name, dtype: object
# ['Page name transparency report: Bill Huizenga']
# 101    Missing list: df_temp2: Bill Huizenga
# Name: full_name, dtype: object
# ['Page name transparency report: Sheila Jackson Lee']
# 102    Missing list: df_temp2: Sheila Jackson Lee
# Name: full_name, dtype: object
# ['Page name transparency report: Bill Johnson Leads']
# 103    Missing list: df_temp2: Bill Johnson
# Name: full_name, dtype: object
# ['Page name transparency report: Ron Johnson']
# 106    Missing list: df_temp2: Ron Johnson
# Name: full_name, dtype: object
# ['Page name transparency report: Jim Jordan for Congress']
# 107    Missing list: df_temp2: Jim Jordan
# Name: full_name, dtype: object
# ['Page name transparency report: Representative Marcy Kaptur']
# 108    Missing list: df_temp2: Marcy Kaptur
# Name: full_name, dtype: object
# ['Page name transparency report: Mike Kelly for Congress']
# 110    Missing list: df_temp2: Mike Kelly
# Name: full_name, dtype: object
# ['Page name transparency report: Ron Kind']
# 111    Missing list: df_temp2: Ron Kind
# Name: full_name, dtype: object
# ['Page name transparency report: Adam Kinzinger']
# 112    Missing list: df_temp2: Adam Kinzinger
# Name: full_name, dtype: object
# ['Page name transparency report: Vote No on Doug Lamborn']
# 113    Missing list: df_temp2: Doug Lamborn
# Name: full_name, dtype: object
# ['Page name transparency report: James Lankford']
# 115    Missing list: df_temp2: James Lankford
# Name: full_name, dtype: object
# ['Page name transparency report: Rick Larsen']
# 116    Missing list: df_temp2: Rick Larsen
# Name: full_name, dtype: object
# ['Page name transparency report: John B. Larson']
# 117    Missing list: df_temp2: John B. Larson
# Name: full_name, dtype: object
# ['Page name transparency report: Barbara Lee']
# 120    Missing list: df_temp2: Barbara Lee
# Name: full_name, dtype: object
# ['Page name transparency report: Mike Lee']
# 121    Missing list: df_temp2: Mike Lee
# Name: full_name, dtype: object
# ['Page name transparency report: Zoe Lofgren']
# 122    Missing list: df_temp2: Zoe Lofgren
# Name: full_name, dtype: object
# ['Page name transparency report: Billy Long For Senate']
# 123    Missing list: df_temp2: Billy Long
# Name: full_name, dtype: object
# ['Page name transparency report: Blaine Luetkemeyer']
# 125    Missing list: df_temp2: Blaine Luetkemeyer
# Name: full_name, dtype: object
# ['Page name transparency report: Ben Ray Luján']
# 126    Missing list: df_temp2: Ben Ray Luján
# Name: full_name, dtype: object
# ['Page name transparency report: Stephen F. Lynch']
# 127    Missing list: df_temp2: Stephen F. Lynch
# Name: full_name, dtype: object
# ['Page name transparency report: Carolyn B. Maloney']
# 128    Missing list: df_temp2: Carolyn B. Maloney
# Name: full_name, dtype: object
# ['Page name transparency report: Tom McClintock']
# 133    Missing list: df_temp2: Tom McClintock
# Name: full_name, dtype: object
# ['Page name transparency report: Betty McCollum for Congress']
# 134    Missing list: df_temp2: Betty McCollum
# Name: full_name, dtype: object
# ['Page name transparency report: Cathy McMorris Rodgers']
# 138    Missing list: df_temp2: Cathy McMorris Rodgers
# Name: full_name, dtype: object
# ['Page name transparency report: Jerry McNerney']
# 139    Missing list: df_temp2: Jerry McNerney
# Name: full_name, dtype: object
# ['Page name transparency report: Gwen Moore for Congress']
# 141    Missing list: df_temp2: Gwen Moore
# Name: full_name, dtype: object
# ['Page name transparency report: Christopher Murphy for Leavenworth City Commissioner']
# 144    Missing list: df_temp2: Christopher Murphy
# Name: full_name, dtype: object
# ['Page name transparency report: Eleanor Holmes Norton for US Congress']
# 149    Missing list: df_temp2: Eleanor Holmes Norton
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman Bill Pascrell, Jr.']
# 153    Missing list: df_temp2: Bill Pascrell, Jr.
# Name: full_name, dtype: object
# ['Page name transparency report: Rand Paul']
# 154    Missing list: df_temp2: Rand Paul
# Name: full_name, dtype: object
# ['Page name transparency report: Nancy Pelosi']
# 155    Missing list: df_temp2: Nancy Pelosi
# Name: full_name, dtype: object
# ['Page name transparency report: Ed Perlmutter']
# 156    Missing list: df_temp2: Ed Perlmutter
# Name: full_name, dtype: object
# ['Page name transparency report: Chellie Pingree']
# 158    Missing list: df_temp2: Chellie Pingree
# Name: full_name, dtype: object
# ['Page name transparency report: Senator Rob Portman']
# 159    Missing list: df_temp2: Rob Portman
# Name: full_name, dtype: object
# ['Page name transparency report: Bill Posey for Congress']
# 160    Missing list: df_temp2: Bill Posey
# Name: full_name, dtype: object
# ['Page name transparency report: Mike Quigley']
# 162    Missing list: df_temp2: Mike Quigley
# Name: full_name, dtype: object
# ['Page name transparency report: Tom Reed']
# 163    Missing list: df_temp2: Tom Reed
# Name: full_name, dtype: object
# ['Page name transparency report: Mike Rogers']
# 165    Missing list: df_temp2: Mike Rogers
# Name: full_name, dtype: object
# ['Page name transparency report: Lucille Roybal-Allard']
# 166    Missing list: df_temp2: Lucille Roybal-Allard
# Name: full_name, dtype: object
# ['Page name transparency report: Marco Rubio']
# 167    Missing list: df_temp2: Marco Rubio
# Name: full_name, dtype: object
# ['Page name transparency report: Tim Ryan']
# 170    Missing list: df_temp2: Tim Ryan
# Name: full_name, dtype: object
# ['Page name transparency report: Gregorio Kilili Camacho Sablan']
# 171    Missing list: df_temp2: Gregorio Kilili Camach...
# Name: full_name, dtype: object
# ['Page name transparency report: Steve Scalise']
# 173    Missing list: df_temp2: Steve Scalise
# Name: full_name, dtype: object
# ['Page name transparency report: Kurt Schrader']
# 176    Missing list: df_temp2: Kurt Schrader
# Name: full_name, dtype: object
# ['Page name transparency report: David Schweikert']
# 178    Missing list: df_temp2: David Schweikert
# Name: full_name, dtype: object
# ['Page name transparency report: Rep. Austin Scott']
# 179    Missing list: df_temp2: Austin Scott
# Name: full_name, dtype: object
# ['Page name transparency report: David Scott for Congress']
# 180    Missing list: df_temp2: David Scott
# Name: full_name, dtype: object
# ['Page name transparency report: Tim Scott']
# 182    Missing list: df_temp2: Tim Scott
# Name: full_name, dtype: object
# ['Page name transparency report: Terri Sewell']
# 183    Missing list: df_temp2: Terri Sewell
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman Brad Sherman']
# 185    Missing list: df_temp2: Brad Sherman
# Name: full_name, dtype: object
# ['Page name transparency report: Albio Sires for NJ']
# 187    Missing list: df_temp2: Albio Sires
# Name: full_name, dtype: object
# ['Page name transparency report: Adam Smith for Congress']
# 188    Missing list: df_temp2: Adam Smith
# Name: full_name, dtype: object
# ['Page name transparency report: Adrian Smith']
# 189    Missing list: df_temp2: Adrian Smith
# Name: full_name, dtype: object
# ['Page name transparency report: Congresswoman Jackie Speier']
# 191    Missing list: df_temp2: Jackie Speier
# Name: full_name, dtype: object
# ['Page name transparency report: Kansas Senator Mike Thompson']
# 194    Missing list: df_temp2: Mike Thompson
# Name: full_name, dtype: object
# ['Page name transparency report: Friends of Glenn Thompson - Team GT']
# 195    Missing list: df_temp2: Glenn Thompson
# Name: full_name, dtype: object
# ['Page name transparency report: John Thune']
# 196    Missing list: df_temp2: John Thune
# Name: full_name, dtype: object
# ['Page name transparency report: Paul Tonko for Congress']
# 197    Missing list: df_temp2: Paul Tonko
# Name: full_name, dtype: object
# ['Page name transparency report: Chris Van Hollen']
# 201    Missing list: df_temp2: Chris Van Hollen
# Name: full_name, dtype: object
# ['Page name transparency report: Tim Walberg']
# 203    Missing list: df_temp2: Tim Walberg
# Name: full_name, dtype: object
# ['Page name transparency report: Debbie Wasserman Schultz']
# 204    Missing list: df_temp2: Debbie Wasserman Schultz
# Name: full_name, dtype: object
# ['Page name transparency report: Latinos For Congresswoman Maxine Waters']
# 205    Missing list: df_temp2: Maxine Waters
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman Daniel Webster']
# 206    Missing list: df_temp2: Daniel Webster
# Name: full_name, dtype: object
# ['Page name transparency report: Joe Wilson']
# 208    Missing list: df_temp2: Joe Wilson
# Name: full_name, dtype: object
# ['Page name transparency report: Ron Wyden']
# 212    Missing list: df_temp2: Ron Wyden
# Name: full_name, dtype: object
# ['Page name transparency report: Don Young']
# 214    Missing list: df_temp2: Don Young
# Name: full_name, dtype: object
# ['Page name transparency report: Todd Young']
# 215    Missing list: df_temp2: Todd Young
# Name: full_name, dtype: object
# ['Page name transparency report: Suzanne Bonamici']
# 217    Missing list: df_temp2: Suzanne Bonamici
# Name: full_name, dtype: object
# ['Page name transparency report: Thomas Massie']
# 219    Missing list: df_temp2: Thomas Massie
# Name: full_name, dtype: object
# ['Page name transparency report: Brian Schatz']
# 221    Missing list: df_temp2: Brian Schatz
# Name: full_name, dtype: object
# ['Page name transparency report: Bill Foster']
# 222    Missing list: df_temp2: Bill Foster
# Name: full_name, dtype: object
# ['Page name transparency report: Dina Titus']
# 223    Missing list: df_temp2: Dina Titus
# Name: full_name, dtype: object
# ['Page name transparency report: Tom Cotton']
# 224    Missing list: df_temp2: Tom Cotton
# Name: full_name, dtype: object
# ['Page name transparency report: Kyrsten Sinema']
# 225    Missing list: df_temp2: Kyrsten Sinema
# Name: full_name, dtype: object
# ['Page name transparency report: Doug LaMalfa']
# 226    Missing list: df_temp2: Doug LaMalfa
# Name: full_name, dtype: object
# ['Page name transparency report: Jared Huffman']
# 227    Missing list: df_temp2: Jared Huffman
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman Ami Bera']
# 228    Missing list: df_temp2: Ami Bera
# Name: full_name, dtype: object
# ['Page name transparency report: Eric Swalwell']
# 229    Missing list: df_temp2: Eric Swalwell
# Name: full_name, dtype: object
# ['Page name transparency report: Julia Brownley for Congress']
# 230    Missing list: df_temp2: Julia Brownley
# Name: full_name, dtype: object
# ['Page name transparency report: U.S. Rep. Tony Cárdenas']
# 231    Missing list: df_temp2: Tony Cárdenas
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman Raul Ruiz, MD']
# 232    Missing list: df_temp2: Raul Ruiz
# Name: full_name, dtype: object
# ['Page name transparency report: Mark Takano']
# 233    Missing list: df_temp2: Mark Takano
# Name: full_name, dtype: object
# ['Page name transparency report: Juan Vargas for Congress']
# 235    Missing list: df_temp2: Juan Vargas
# Name: full_name, dtype: object
# ['Page name transparency report: Lois Frankel']
# 237    Missing list: df_temp2: Lois Frankel
# Name: full_name, dtype: object
# ['Page name transparency report: Tammy Duckworth']
# 238    Missing list: df_temp2: Tammy Duckworth
# Name: full_name, dtype: object
# ['Page name transparency report: Rodney Davis']
# 239    Missing list: df_temp2: Rodney Davis
# Name: full_name, dtype: object
# ['Page name transparency report: Cheri Bustos']
# 240    Missing list: df_temp2: Cheri Bustos
# Name: full_name, dtype: object
# ['Page name transparency report: Jackie Walorski']
# 241    Missing list: df_temp2: Jackie Walorski
# Name: full_name, dtype: object
# ['Page name transparency report: Andy Barr']
# 242    Missing list: df_temp2: Andy Barr
# Name: full_name, dtype: object
# ['Page name transparency report: Ann Wagner']
# 246    Missing list: df_temp2: Ann Wagner
# Name: full_name, dtype: object
# ['Page name transparency report: Steve Daines']
# 247    Missing list: df_temp2: Steve Daines
# Name: full_name, dtype: object
# ['Page name transparency report: Dirty Money Richard Hudson']
# 248    Missing list: df_temp2: Richard Hudson
# Name: full_name, dtype: object
# ['Page name transparency report: Kevin Cramer']
# 249    Missing list: df_temp2: Kevin Cramer
# Name: full_name, dtype: object
# ['Page name transparency report: Deb Fischer']
# 250    Missing list: df_temp2: Deb Fischer
# Name: full_name, dtype: object
# ['Page name transparency report: Grace Meng']
# 252    Missing list: df_temp2: Grace Meng
# Name: full_name, dtype: object
# ['Page name transparency report: Sean Patrick Maloney']
# 254    Missing list: df_temp2: Sean Patrick Maloney
# Name: full_name, dtype: object
# ['Page name transparency report: Joyce Beatty for Congress']
# 256    Missing list: df_temp2: Joyce Beatty
# Name: full_name, dtype: object
# ['Page name transparency report: Markwayne Mullin']
# 258    Missing list: df_temp2: Markwayne Mullin
# Name: full_name, dtype: object
# ['Page name transparency report: Scott Perry for Congress']
# 259    Missing list: df_temp2: Scott Perry
# Name: full_name, dtype: object
# ['Page name transparency report: Matt Cartwright for U.S. Congress']
# 260    Missing list: df_temp2: Matt Cartwright
# Name: full_name, dtype: object
# ['Page name transparency report: Tom Rice for Congress']
# 261    Missing list: df_temp2: Tom Rice
# Name: full_name, dtype: object
# ['Page name transparency report: Ted Cruz']
# 262    Missing list: df_temp2: Ted Cruz
# Name: full_name, dtype: object
# ['Page name transparency report: Joaquin Castro']
# 264    Missing list: df_temp2: Joaquin Castro
# Name: full_name, dtype: object
# ['Page name transparency report: Roger Williams']
# 265    Missing list: df_temp2: Roger Williams
# Name: full_name, dtype: object
# ['Page name transparency report: Filemon Vela']
# 267    Missing list: df_temp2: Filemon Vela
# Name: full_name, dtype: object
# ['Page name transparency report: Chris Stewart']
# 268    Missing list: df_temp2: Chris Stewart
# Name: full_name, dtype: object
# ['Page name transparency report: Tim Kaine']
# 269    Missing list: df_temp2: Tim Kaine
# Name: full_name, dtype: object
# ['Page name transparency report: Friends of Derek Kilmer']
# 270    Missing list: df_temp2: Derek Kilmer
# Name: full_name, dtype: object
# ['Page name transparency report: Mark Pocan']
# 271    Missing list: df_temp2: Mark Pocan
# Name: full_name, dtype: object
# ['Page name transparency report: Jason Smith']
# 273    Missing list: df_temp2: Jason Smith
# Name: full_name, dtype: object
# ['Page name transparency report: Donald Norcross for Congress']
# 276    Missing list: df_temp2: Donald Norcross
# Name: full_name, dtype: object
# ['Page name transparency report: Detroit Caring Dentistry directed by Dr. David J. Hill DDS']
# 279    Missing list: df_temp2: J. Hill
# Name: full_name, dtype: object
# ['Page name transparency report: Bruce Westerman']
# 280    Missing list: df_temp2: Bruce Westerman
# Name: full_name, dtype: object
# ['Page name transparency report: Ruben Gallego']
# 281    Missing list: df_temp2: Ruben Gallego
# Name: full_name, dtype: object
# ['Page name transparency report: Mark DeSaulnier']
# 282    Missing list: df_temp2: Mark DeSaulnier
# Name: full_name, dtype: object
# ['Page name transparency report: Pete Aguilar for Congress']
# 283    Missing list: df_temp2: Pete Aguilar
# Name: full_name, dtype: object
# ['Page name transparency report: Ted Lieu']
# 284    Missing list: df_temp2: Ted Lieu
# Name: full_name, dtype: object
# ['Page name transparency report: Ken Buck']
# 286    Missing list: df_temp2: Ken Buck
# Name: full_name, dtype: object
# ['Page name transparency report: Barry Loudermilk']
# 289    Missing list: df_temp2: Barry Loudermilk
# Name: full_name, dtype: object
# ['Page name transparency report: Mike Bost']
# 291    Missing list: df_temp2: Mike Bost
# Name: full_name, dtype: object
# ['Page name transparency report: Garret Graves']
# 292    Missing list: df_temp2: Garret Graves
# Name: full_name, dtype: object
# ['Page name transparency report: Seth Moulton']
# 293    Missing list: df_temp2: Seth Moulton
# Name: full_name, dtype: object
# ['Page name transparency report: Debbie Dingell']
# 295    Missing list: df_temp2: Debbie Dingell
# Name: full_name, dtype: object
# ['Page name transparency report: Tom Emmer for Congress']
# 297    Missing list: df_temp2: Tom Emmer
# Name: full_name, dtype: object
# ['Page name transparency report: David Rouzer']
# 298    Missing list: df_temp2: David Rouzer
# Name: full_name, dtype: object
# ['Page name transparency report: Bonnie Watson Coleman for Congress']
# 299    Missing list: df_temp2: Bonnie Watson Coleman
# Name: full_name, dtype: object
# ['Page name transparency report: John Katko for Congress']
# 303    Missing list: df_temp2: John Katko
# Name: full_name, dtype: object
# ['Page name transparency report: Dr. Brian Babin']
# 305    Missing list: df_temp2: Brian Babin
# Name: full_name, dtype: object
# ['Page name transparency report: Dan Newhouse for Congress']
# 308    Missing list: df_temp2: Dan Newhouse
# Name: full_name, dtype: object
# ['Page name transparency report: Dan Sullivan']
# 312    Missing list: df_temp2: Dan Sullivan
# Name: full_name, dtype: object
# ['Page name transparency report: Joni Ernst']
# 313    Missing list: df_temp2: Joni Ernst
# Name: full_name, dtype: object
# ['Page name transparency report: Corrupt Thom Tillis']
# 314    Missing list: df_temp2: Thom Tillis
# Name: full_name, dtype: object
# ['Page name transparency report: Mike Rounds']
# 315    Missing list: df_temp2: Mike Rounds
# Name: full_name, dtype: object
# ['Page name transparency report: Ben Sasse']
# 316    Missing list: df_temp2: Ben Sasse
# Name: full_name, dtype: object
# ['Page name transparency report: Trent Kelly']
# 317    Missing list: df_temp2: Trent Kelly
# Name: full_name, dtype: object
# ['Page name transparency report: Darin LaHood']
# 318    Missing list: df_temp2: Darin LaHood
# Name: full_name, dtype: object
# ['Page name transparency report: Warren Davidson For Congress']
# 319    Missing list: df_temp2: Warren Davidson
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman James Comer']
# 320    Missing list: df_temp2: James Comer
# Name: full_name, dtype: object
# ['Page name transparency report: Dwight Evans']
# 321    Missing list: df_temp2: Dwight Evans
# Name: full_name, dtype: object
# ['Page name transparency report: John Kennedy for Suffolk']
# 322    Missing list: df_temp2: John Kennedy
# Name: full_name, dtype: object
# ['Page name transparency report: Catherine Cortez Masto']
# 324    Missing list: df_temp2: Catherine Cortez Masto
# Name: full_name, dtype: object
# ['Page name transparency report: Andy Biggs']
# 327    Missing list: df_temp2: Andy Biggs
# Name: full_name, dtype: object
# ['Page name transparency report: Jimmy Panetta for Congress']
# 329    Missing list: df_temp2: Jimmy Panetta
# Name: full_name, dtype: object
# ['Page name transparency report: US Rep Nanette Diaz Barragán']
# 331    Missing list: df_temp2: Nanette Diaz Barragán
# Name: full_name, dtype: object
# ['Page name transparency report: Lisa Blunt Rochester']
# 333    Missing list: df_temp2: Lisa Blunt Rochester
# Name: full_name, dtype: object
# ['Page name transparency report: Matt Gaetz']
# 334    Missing list: df_temp2: Matt Gaetz
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman Darren Soto: Our Progressive Champion']
# 339    Missing list: df_temp2: Darren Soto
# Name: full_name, dtype: object
# ['Page name transparency report: Charlie Crist']
# 341    Missing list: df_temp2: Charlie Crist
# Name: full_name, dtype: object
# ['Page name transparency report: Jim Banks']
# 345    Missing list: df_temp2: Jim Banks
# Name: full_name, dtype: object
# ['Page name transparency report: Representative Trey Hollingsworth']
# 346    Missing list: df_temp2: Trey Hollingsworth
# Name: full_name, dtype: object
# ['Page name transparency report: Dr. Roger Marshall']
# 347    Missing list: df_temp2: Roger Marshall
# Name: full_name, dtype: object
# ['Page name transparency report: Captain Clay Higgins']
# 348    Missing list: df_temp2: Clay Higgins
# Name: full_name, dtype: object
# ['Page name transparency report: Mike Johnson']
# 349    Missing list: df_temp2: Mike Johnson
# Name: full_name, dtype: object
# ['Page name transparency report: Anthony Brown']
# 350    Missing list: df_temp2: Anthony Brown
# Name: full_name, dtype: object
# ['Page name transparency report: Jamie Raskin']
# 351    Missing list: df_temp2: Jamie Raskin
# Name: full_name, dtype: object
# ['Page name transparency report: Rep. Jack Bergman']
# 352    Missing list: df_temp2: Jack Bergman
# Name: full_name, dtype: object
# ['Page name transparency report: Ted Budd']
# 353    Missing list: df_temp2: Ted Budd
# Name: full_name, dtype: object
# ['Page name transparency report: Hell No, Don Bacon']
# 354    Missing list: df_temp2: Don Bacon
# Name: full_name, dtype: object
# ['Page name transparency report: Josh Gottheimer for Congress']
# 355    Missing list: df_temp2: Josh Gottheimer
# Name: full_name, dtype: object
# ['Page name transparency report: Jacky Rosen for Nevada']
# 356    Missing list: df_temp2: Jacky Rosen
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman Adriano Espaillat']
# 358    Missing list: df_temp2: Adriano Espaillat
# Name: full_name, dtype: object
# ['Page name transparency report: Lloyd Smucker']
# 360    Missing list: df_temp2: Lloyd Smucker
# Name: full_name, dtype: object
# ['Page name transparency report: David Kustoff']
# 362    Missing list: df_temp2: David Kustoff
# Name: full_name, dtype: object
# ['Page name transparency report: U.S. Congressman Vicente Gonzalez 2022']
# 363    Missing list: df_temp2: Vicente Gonzalez
# Name: full_name, dtype: object
# ['Page name transparency report: A. Donald McEachin']
# 365    Missing list: df_temp2: A. Donald McEachin
# Name: full_name, dtype: object
# ['Page name transparency report: Pramila Jayapal']
# 366    Missing list: df_temp2: Pramila Jayapal
# Name: full_name, dtype: object
# ['Page name transparency report: Mike Gallagher']
# 367    Missing list: df_temp2: Mike Gallagher
# Name: full_name, dtype: object
# ['Page name transparency report: Liz Cheney']
# 368    Missing list: df_temp2: Liz Cheney
# Name: full_name, dtype: object
# ['Page name transparency report: Ron Estes']
# 369    Missing list: df_temp2: Ron Estes
# Name: full_name, dtype: object
# ['Page name transparency report: Rep. Ralph Norman']
# 370    Missing list: df_temp2: Ralph Norman
# Name: full_name, dtype: object
# ['Page name transparency report: Rep. Jimmy Gomez']
# 371    Missing list: df_temp2: Jimmy Gomez
# Name: full_name, dtype: object
# ['Page name transparency report: Tina Smith']
# 373    Missing list: df_temp2: Tina Smith
# Name: full_name, dtype: object
# ['Page name transparency report: Cindy Hyde-Smith']
# 374    Missing list: df_temp2: Cindy Hyde-Smith
# Name: full_name, dtype: object
# ['Page name transparency report: Conor Lamb']
# 375    Missing list: df_temp2: Conor Lamb
# Name: full_name, dtype: object
# ['Page name transparency report: Congresswoman Debbie Lesko']
# 376    Missing list: df_temp2: Debbie Lesko
# Name: full_name, dtype: object
# ['Page name transparency report: Michael Cloud']
# 377    Missing list: df_temp2: Michael Cloud
# Name: full_name, dtype: object
# ['Page name transparency report: Troy Balderson for Congress']
# 378    Missing list: df_temp2: Troy Balderson
# Name: full_name, dtype: object
# ['Page name transparency report: Representative Kevin Hern']
# 379    Missing list: df_temp2: Kevin Hern
# Name: full_name, dtype: object
# ['Page name transparency report: Mary Gay Scanlon']
# 381    Missing list: df_temp2: Mary Gay Scanlon
# Name: full_name, dtype: object
# ['Page name transparency report: Susan Wild for Congress']
# 382    Missing list: df_temp2: Susan Wild
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman Ed Case']
# 383    Missing list: df_temp2: Ed Case
# Name: full_name, dtype: object
# ['Page name transparency report: Steven Horsford']
# 384    Missing list: df_temp2: Steven Horsford
# Name: full_name, dtype: object
# ['Page name transparency report: Ann Kirkpatrick']
# 385    Missing list: df_temp2: Ann Kirkpatrick
# Name: full_name, dtype: object
# ['Page name transparency report: Representative Greg Stanton']
# 386    Missing list: df_temp2: Greg Stanton
# Name: full_name, dtype: object
# ['Page name transparency report: Josh Harder']
# 387    Missing list: df_temp2: Josh Harder
# Name: full_name, dtype: object
# ['Page name transparency report: Katie Porter']
# 388    Missing list: df_temp2: Katie Porter
# Name: full_name, dtype: object
# ['Page name transparency report: Mike Levin']
# 389    Missing list: df_temp2: Mike Levin
# Name: full_name, dtype: object
# ['Page name transparency report: Joe Neguse']
# 390    Missing list: df_temp2: Joe Neguse
# Name: full_name, dtype: object
# ['Page name transparency report: Jason Crow']
# 391    Missing list: df_temp2: Jason Crow
# Name: full_name, dtype: object
# ['Page name transparency report: Jahana Hayes']
# 392    Missing list: df_temp2: Jahana Hayes
# Name: full_name, dtype: object
# ['Page name transparency report: Representative Michael Waltz']
# 393    Missing list: df_temp2: Michael Waltz
# Name: full_name, dtype: object
# ['Page name transparency report: Lucy McBath for Congress']
# 395    Missing list: df_temp2: Lucy McBath
# Name: full_name, dtype: object
# ['Page name transparency report: Rep. Russ Fulcher']
# 398    Missing list: df_temp2: Russ Fulcher
# Name: full_name, dtype: object
# ['Page name transparency report: Sean Casten for Congress']
# 400    Missing list: df_temp2: Sean Casten
# Name: full_name, dtype: object
# ['Page name transparency report: Lauren Underwood for Congress']
# 401    Missing list: df_temp2: Lauren Underwood
# Name: full_name, dtype: object
# ['Page name transparency report: U.S. Representative Greg Pence']
# 403    Missing list: df_temp2: Greg Pence
# Name: full_name, dtype: object
# ['Page name transparency report: Representative Sharice Davids']
# 404    Missing list: df_temp2: Sharice Davids
# Name: full_name, dtype: object
# ['Page name transparency report: Lori Trahan']
# 405    Missing list: df_temp2: Lori Trahan
# Name: full_name, dtype: object
# ['Page name transparency report: Ayanna Pressley']
# 406    Missing list: df_temp2: Ayanna Pressley
# Name: full_name, dtype: object
# ['Page name transparency report: Elissa Slotkin']
# 408    Missing list: df_temp2: Elissa Slotkin
# Name: full_name, dtype: object
# ['Page name transparency report: Andy Levin']
# 409    Missing list: df_temp2: Andy Levin
# Name: full_name, dtype: object
# ['Page name transparency report: Rashida Tlaib']
# 411    Missing list: df_temp2: Rashida Tlaib
# Name: full_name, dtype: object
# ['Page name transparency report: Swampy Jim Hagedorn']
# 412    Missing list: df_temp2: Jim Hagedorn
# Name: full_name, dtype: object
# ['Page name transparency report: Angie Craig']
# 413    Missing list: df_temp2: Angie Craig
# Name: full_name, dtype: object
# ['Page name transparency report: Dean Phillips for Congress']
# 414    Missing list: df_temp2: Dean Phillips
# Name: full_name, dtype: object
# ['Page name transparency report: Ilhan Omar']
# 415    Missing list: df_temp2: Ilhan Omar
# Name: full_name, dtype: object
# ['Page name transparency report: Pete Stauber']
# 416    Missing list: df_temp2: Pete Stauber
# Name: full_name, dtype: object
# ['Page name transparency report: Michael Guest']
# 417    Missing list: df_temp2: Michael Guest
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman Kelly Armstrong']
# 418    Missing list: df_temp2: Kelly Armstrong
# Name: full_name, dtype: object
# ['Page name transparency report: Chris Pappas for Congress']
# 419    Missing list: df_temp2: Chris Pappas
# Name: full_name, dtype: object
# ['Page name transparency report: Andy Kim for Congress']
# 421    Missing list: df_temp2: Andy Kim
# Name: full_name, dtype: object
# ['Page name transparency report: Tom Malinowski for Congress']
# 422    Missing list: df_temp2: Tom Malinowski
# Name: full_name, dtype: object
# ['Page name transparency report: Mikie Sherrill']
# 423    Missing list: df_temp2: Mikie Sherrill
# Name: full_name, dtype: object
# ['Page name transparency report: Susie Lee']
# 424    Missing list: df_temp2: Susie Lee
# Name: full_name, dtype: object
# ['Page name transparency report: Alexandria Ocasio-Cortez']
# 425    Missing list: df_temp2: Alexandria Ocasio-Cortez
# Name: full_name, dtype: object
# ['Page name transparency report: Antonio Delgado']
# 426    Missing list: df_temp2: Antonio Delgado
# Name: full_name, dtype: object
# ['Page name transparency report: Anthony Gonzalez for Congress']
# 427    Missing list: df_temp2: Anthony Gonzalez
# Name: full_name, dtype: object
# ['Page name transparency report: Chrissy Houlahan']
# 429    Missing list: df_temp2: Chrissy Houlahan
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman Guy Reschenthaler']
# 432    Missing list: df_temp2: Guy Reschenthaler
# Name: full_name, dtype: object
# ['Page name transparency report: Rep. Dusty Johnson']
# 434    Missing list: df_temp2: Dusty Johnson
# Name: full_name, dtype: object
# ['Page name transparency report: Tim Burchett for Congress']
# 435    Missing list: df_temp2: Tim Burchett
# Name: full_name, dtype: object
# ['Page name transparency report: John Rose for Tennessee']
# 436    Missing list: df_temp2: John Rose
# Name: full_name, dtype: object
# ['Page name transparency report: Dan Crenshaw']
# 438    Missing list: df_temp2: Dan Crenshaw
# Name: full_name, dtype: object
# ['Page name transparency report: Van Taylor']
# 439    Missing list: df_temp2: Van Taylor
# Name: full_name, dtype: object
# ['Page name transparency report: Lance Gooden']
# 440    Missing list: df_temp2: Lance Gooden
# Name: full_name, dtype: object
# ['Page name transparency report: Congresswoman Lizzie Fletcher']
# 441    Missing list: df_temp2: Lizzie Fletcher
# Name: full_name, dtype: object
# ['Page name transparency report: Veronica Escobar']
# 442    Missing list: df_temp2: Veronica Escobar
# Name: full_name, dtype: object
# ['Page name transparency report: Chip Roy']
# 443    Missing list: df_temp2: Chip Roy
# Name: full_name, dtype: object
# ['Page name transparency report: Ben Cline']
# 447    Missing list: df_temp2: Ben Cline
# Name: full_name, dtype: object
# ['Page name transparency report: Jennifer Wexton']
# 449    Missing list: df_temp2: Jennifer Wexton
# Name: full_name, dtype: object
# ['Page name transparency report: Bryan Steil']
# 451    Missing list: df_temp2: Bryan Steil
# Name: full_name, dtype: object
# ['Page name transparency report: Rick Scott Is Not For Florida']
# 453    Missing list: df_temp2: Rick Scott
# Name: full_name, dtype: object
# ['Page name transparency report: Mike Braun']
# 454    Missing list: df_temp2: Mike Braun
# Name: full_name, dtype: object
# ['Page name transparency report: Josh Hawley']
# 455    Missing list: df_temp2: Josh Hawley
# Name: full_name, dtype: object
# ['Page name transparency report: Patriot Mitt Romney']
# 456    Missing list: df_temp2: Mitt Romney
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman Fred Keller']
# 458    Missing list: df_temp2: Fred Keller
# Name: full_name, dtype: object
# ['Page name transparency report: Dan Bishop']
# 459    Missing list: df_temp2: Dan Bishop
# Name: full_name, dtype: object
# ['Page name transparency report: Kweisi Mfume']
# 461    Missing list: df_temp2: Kweisi Mfume
# Name: full_name, dtype: object
# ['Page name transparency report: Mike Garcia for Congress']
# 463    Missing list: df_temp2: Mike Garcia
# Name: full_name, dtype: object
# ['Page name transparency report: Senator Chris Jacobs']
# 464    Missing list: df_temp2: Chris Jacobs
# Name: full_name, dtype: object
# ['Page name transparency report: Captain Mark Kelly']
# 465    Missing list: df_temp2: Mark Kelly
# Name: full_name, dtype: object
# ['Page name transparency report: Darrell Issa']
# 467    Missing list: df_temp2: Darrell Issa
# Name: full_name, dtype: object
# ['Page name transparency report: Pete Sessions']
# 468    Missing list: df_temp2: Pete Sessions
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman David G. Valadao']
# 469    Missing list: df_temp2: David G. Valadao
# Name: full_name, dtype: object
# ['Page name transparency report: Tommy Tuberville']
# 470    Missing list: df_temp2: Tommy Tuberville
# Name: full_name, dtype: object
# ['Page name transparency report: John W. Hickenlooper']
# 471    Missing list: df_temp2: John W. Hickenlooper
# Name: full_name, dtype: object
# ['Page name transparency report: Bill Hagerty']
# 472    Missing list: df_temp2: Bill Hagerty
# Name: full_name, dtype: object
# ['Page name transparency report: Barry Moore Republican for Congress']
# 474    Missing list: df_temp2: Barry Moore
# Name: full_name, dtype: object
# ['Page name transparency report: Jay Obernolte']
# 475    Missing list: df_temp2: Jay Obernolte
# Name: full_name, dtype: object
# ['Page name transparency report: Young Kim']
# 476    Missing list: df_temp2: Young Kim
# Name: full_name, dtype: object
# ['Page name transparency report: Michelle Steel']
# 477    Missing list: df_temp2: Michelle Steel
# Name: full_name, dtype: object
# ['Page name transparency report: Sara Jacobs']
# 478    Missing list: df_temp2: Sara Jacobs
# Name: full_name, dtype: object
# ['Page name transparency report: Lauren Boebert for Congress']
# 479    Missing list: df_temp2: Lauren Boebert
# Name: full_name, dtype: object
# ['Page name transparency report: Kat Cammack']
# 480    Missing list: df_temp2: Kat Cammack
# Name: full_name, dtype: object
# ['Page name transparency report: Byron Donalds']
# 482    Missing list: df_temp2: Byron Donalds
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman Carlos A. Gimenez']
# 483    Missing list: df_temp2: Carlos A. Gimenez
# Name: full_name, dtype: object
# ['Page name transparency report: Maria Elvira Salazar']
# 484    Missing list: df_temp2: Maria Elvira Salazar
# Name: full_name, dtype: object
# ['Page name transparency report: Nikema Williams']
# 485    Missing list: df_temp2: Nikema Williams
# Name: full_name, dtype: object
# ['Page name transparency report: Carolyn Bourdeaux for Congress']
# 486    Missing list: df_temp2: Carolyn Bourdeaux
# Name: full_name, dtype: object
# ['Page name transparency report: Ashley Hinson']
# 490    Missing list: df_temp2: Ashley Hinson
# Name: full_name, dtype: object
# ['Page name transparency report: Mariannette Miller-Meeks']
# 491    Missing list: df_temp2: Mariannette Miller-Meeks
# Name: full_name, dtype: object
# ['Page name transparency report: Randy Feenstra']
# 492    Missing list: df_temp2: Randy Feenstra
# Name: full_name, dtype: object
# ['Page name transparency report: Marie Newman']
# 493    Missing list: df_temp2: Marie Newman
# Name: full_name, dtype: object
# ['Page name transparency report: Victoria Spartz']
# 496    Missing list: df_temp2: Victoria Spartz
# Name: full_name, dtype: object
# ['Page name transparency report: Tracey Mann']
# 497    Missing list: df_temp2: Tracey Mann
# Name: full_name, dtype: object
# ['Page name transparency report: Jake LaTurner']
# 498    Missing list: df_temp2: Jake LaTurner
# Name: full_name, dtype: object
# ['Page name transparency report: Jake Auchincloss']
# 499    Missing list: df_temp2: Jake Auchincloss
# Name: full_name, dtype: object
# ['Page name transparency report: Peter Meijer']
# 500    Missing list: df_temp2: Peter Meijer
# Name: full_name, dtype: object
# ['Page name transparency report: Michelle Fischbach for Congress']
# 502    Missing list: df_temp2: Michelle Fischbach
# Name: full_name, dtype: object
# ['Page name transparency report: Cori Bush']
# 503    Missing list: df_temp2: Cori Bush
# Name: full_name, dtype: object
# ['Page name transparency report: Madison Cawthorn']
# 507    Missing list: df_temp2: Madison Cawthorn
# Name: full_name, dtype: object
# ['Page name transparency report: Yvette Herrell: Out for Herself']
# 508    Missing list: df_temp2: Yvette Herrell
# Name: full_name, dtype: object
# ['Page name transparency report: Teresa Leger Fernandez']
# 509    Missing list: df_temp2: Teresa Leger Fernandez
# Name: full_name, dtype: object
# ['Page name transparency report: Nicole Malliotakis for Congress']
# 511    Missing list: df_temp2: Nicole Malliotakis
# Name: full_name, dtype: object
# ['Page name transparency report: Ritchie Torres For Congress']
# 512    Missing list: df_temp2: Ritchie Torres
# Name: full_name, dtype: object
# ['Page name transparency report: Jamaal Bowman']
# 513    Missing list: df_temp2: Jamaal Bowman
# Name: full_name, dtype: object
# ['Page name transparency report: Mondaire Jones']
# 514    Missing list: df_temp2: Mondaire Jones
# Name: full_name, dtype: object
# ['Page name transparency report: Cliff Bentz']
# 516    Missing list: df_temp2: Cliff Bentz
# Name: full_name, dtype: object
# ['Page name transparency report: Nancy Mace']
# 517    Missing list: df_temp2: Nancy Mace
# Name: full_name, dtype: object
# ['Page name transparency report: Rep. Diana Harshbarger']
# 518    Missing list: df_temp2: Diana Harshbarger
# Name: full_name, dtype: object
# ['Page name transparency report: Rep Pat Fallon']
# 519    Missing list: df_temp2: Pat Fallon
# Name: full_name, dtype: object
# ['Page name transparency report: August Pfluger']
# 520    Missing list: df_temp2: August Pfluger
# Name: full_name, dtype: object
# ['Page name transparency report: Ronny Jackson']
# 521    Missing list: df_temp2: Ronny Jackson
# Name: full_name, dtype: object
# ['Page name transparency report: Troy E. Nehls']
# 522    Missing list: df_temp2: Troy E. Nehls
# Name: full_name, dtype: object
# ['Page name transparency report: Tony Gonzales']
# 523    Missing list: df_temp2: Tony Gonzales
# Name: full_name, dtype: object
# ['Page name transparency report: Beth Van Duyne']
# 524    Missing list: df_temp2: Beth Van Duyne
# Name: full_name, dtype: object
# ['Page name transparency report: Burgess Owens']
# 526    Missing list: df_temp2: Burgess Owens
# Name: full_name, dtype: object
# ['Page name transparency report: Bob Good for Congress']
# 527    Missing list: df_temp2: Bob Good
# Name: full_name, dtype: object
# ['Page name transparency report: Marilyn Strickland']
# 528    Missing list: df_temp2: Marilyn Strickland
# Name: full_name, dtype: object
# ['Page name transparency report: Scott Fitzgerald']
# 529    Missing list: df_temp2: Scott Fitzgerald
# Name: full_name, dtype: object
# ['Page name transparency report: Alex Padilla']
# 530    Missing list: df_temp2: Alex Padilla
# Name: full_name, dtype: object
# ['Page name transparency report: Jon Ossoff']
# 531    Missing list: df_temp2: Jon Ossoff
# Name: full_name, dtype: object
# ['Page name transparency report: Claudia Tenney Wrong for NY']
# 533    Missing list: df_temp2: Claudia Tenney
# Name: full_name, dtype: object
# ['Page name transparency report: Julia Letlow']
# 534    Missing list: df_temp2: Julia Letlow
# Name: full_name, dtype: object
# ['Page name transparency report: Congressman Troy A. Carter']
# 535    Missing list: df_temp2: Troy A. Carter
# Name: full_name, dtype: object
# ['Page name transparency report: Jake Ellzey']
# 537    Missing list: df_temp2: Jake Ellzey
# Name: full_name, dtype: object

# %%
#Cleaning the 350 some
dict_faulty = {
    'Doug Lamborn': 'no ad account',
    'Richard Hudson': 'Richard Hudson',
    'Glenn Thompson': 'no ad account', 
    'Maxine Waters': 'no ad account',
    'J. Hill': 'French Hill for Arkansas',
    'Thom Tillis': 'Thom Tillis',
    'John Kennedy': 'John Neely Kennedy',
    'Claudia Tenney':'Rep. Claudia Tenney'
}

# %%
df_for_quality_control[df_for_quality_control.full_name == 'Claudia Tenney']
# Out:
#      Unnamed: 0 first_name last_name       full_name type state  district  \
# 533         533    Claudia    Tenney  Claudia Tenney  rep    NY      22.0
#
#           party facebook page_name  identifier           page_id  \
# 533  Republican      NaN       NaN           0  2220944231249057
#
#     already_fetched
# 533            done

# %%
replace_false_pages(dict_faulty, df_pol, df_transparency_report=df_all_ad_pages)
# Out:
# Doug Lamborn no ad account
# 113
# Richard Hudson Richard Hudson
# 248
# Glenn Thompson no ad account
# 195
# Maxine Waters no ad account
# 205
# J. Hill French Hill for Arkansas
# 279
# Thom Tillis Thom Tillis
# 314
# John Kennedy John Neely Kennedy
# 322
# Claudia Tenney Rep. Claudia Tenney
# 533

# %%
df_pol.iat[533,11]
df_pol['full_name']

if 'Thom Tillis' in dict_faulty.keys():
    print(True)
# Out:
# True

# %%
df_pol['cleaning_update'] = df_pol.apply(lambda x: "modified" if x['full_name'] in dict_faulty.keys() else "", axis=1)

# %%
#df_pol.to_csv('congress_fbNamesV2.csv')

# %%
df_pol_mod = df_pol[df_pol.cleaning_update == 'modified']

df_pol_mod.to_csv('cleaning_update.csv')

# %% [markdown]
# ['Page name transparency report: Friends of Glenn Thompson - Team GT']
# 195    Missing list: df_temp2: Glenn Thompson
#
# ['Page name transparency report: Latinos For Congresswoman Maxine Waters']
# 205    Missing list: df_temp2: Maxine Waters
#
#
# ['Page name transparency report: Friends of Derek Kilmer']
# 270    Missing list: df_temp2: Derek Kilmer
#
#
#
# ['Page name transparency report: Detroit Caring Dentistry directed by Dr. David J. Hill DDS']
# 279    Missing list: df_temp2: J. Hill
#
# quite a few have two ad accounts as well. Both a general account and one specific to a campaign "French Hill for Arkansas" and "Congressman French Hill"
#
#
# 'Corrupt Thom Tillis', 'Defeat Thom Tillis'

# %%
# #df.loc[df['B'].isin(['one','three'])])

# # Two ways to attack this filtering of the data:
# # data.loc[data['page_name'].isin(['Boost the News'])]
# # data.loc[data['page_name'] == 'Boost the News']

# # data['page_name'].str.contains('Boost', 'Climate').any()

# # data['page_name'].filter(regex='Boost')

# # @USCongressmanFilemonVela etc.
# set_of_pol_pgnames = {'USCongressmanFilemonVela', 'reppaultonko', 'SenatorThomTillis', 'DonaldNorcrossNJ', '153423912663', 'repalgreen', 'RepDonBeyer', 'RepRogerWilliams', 'CongressmanSethMoulton', 'replizcheney', 'RepRoybalAllard', 'mitchmcconnell', 'SenatorRandPaul', 'RepSteveScalise', 'RepMoBrooks', 'CongressmanAlexMooney', 'RepJackBergman', 'RepWesterman', 'RepMcEachin', 'CongresswomanAnnieKuster', 'RepFrankLucas', 'CongressmanTedDeutch', 'GwenSMoore', 'RepTedLieu', 'RepGregMurphy', 'senatordebfischer', 'RepBobGibbs', 'AndyHarrisMD', 'WhipHoyer', 'CongressmanMichaelF.Q.SanNicolas', 'congressmangkbutterfield', 'SenatorTimScott', 'RepJohnCurtis', 'CongressmanNadler', '50375006903', 'RepBarbaraLee', 'jeffmerkley', 'JoeManchinIII', 'RepBost', 'CongressmanBuchanan', 'RepJeffDuncan', 'Congressman.Keating', 'RepSewell', 'RepRickCrawford', 'RepChrisStewart', 'zoelofgren', 'CongressmanWarrenDavidson', 'drnealdunnfl2', 'RepTomSuozzi', 'SenatorLankford', 'RepCheri', 'RepKinzinger', 'marshablackburn', 'SenBrianSchatz', 'RepDonBacon', 'SenatorHassan', 'senshelley', 'senatorcantwell', 'BlaineLuetkemeyer', '113303673339', 'RepJohnLarson', 'senatortester', 'RepRouzer', 'RobertAderholt', 'reptrey', 'jameseclyburn', 'RepRichHudson', 'RickScottSenOffice', 'SenGaryPeters', 'repschrader', 'RepKweisiMfume', 'CongressmanSteveCohen', 'senatortammybaldwin', 'RepAdamSchiff', 'RepBobbyScott', 'RepEliseStefanik', 'senatorelizabethwarren', 'CongressmanMattCartwright', 'RepAmiBera', 'CongressmanKevinMcCarthy', 'RepAnthonyBrown', 'repgaramendi', 'CongressmanDavidCicilline', 'RepJimBanks', 'JodeyArrington', 'repgracemeng', 'bill.posey15', 'senatorchriscoons', 'RepTedBudd', 'RepBrianHiggins', 'RepMarkTakano', 'CongressmanBennieGThompson', 'emanuelcleaverii', 'RepMarkDeSaulnier', 'RepHuffman', 'SenatorTomCotton', 'repscottperry', 'RepresentativeValDemings', 'senatorjimrisch', 'ScottDesJarlaisTN04', 'RepLarryBucshon', 'repchuck', 'RepWalberg', 'senbennetco', 'RepLoisFrankel', 'reptomrice', 'CongressmanClayHiggins', 'SenatorJohnHoeven', 'RepBonnie', 'RepHuizenga', 'CongressmanMikeDRogers', 'RepJoyceBeatty', 'SenatorSasse', 'CongressmanMarcVeasey', 'DianaDeGette', 'chrismurphyct', 'gregorymeeksny05', 'CongressmanDKDavis', 'CongresswomanRosaDeLauro', 'senatorbencardin', 'SenatorMikeRounds', 'RepAustinScott', 'mcmorrisrodgers', '152569121550', 'RepJuliaBrownley', 'USSenTinaSmith', 'repmarkpocan', 'timryan', 'herrerabeutler', 'sen.johncornyn', 'repstephenlynch', 'RepJoshG', 'RepJuanVargas', 'CongressmanGuthrie', 'repfrankpallone', '81058818750', 'tomcarper', 'repgosar', 'senjoniernst', 'CongressmanBillFoster', 'repcardenas', 'SenatorKaine', 'RepJimMcGovern', 'RepConorLamb', 'RepAdamSmith', 'RepDavidKustoff', 'RepDebbieLesko', 'RepKathleenRice', 'johnbarrasso', 'SenJackReed', 'RepJimmyPanetta', 'RepSteveChabot', 'reprobinkelly', 'pascrell', 'CongressmanKevinCramer', 'CongressmanGarretGraves', 'JohnKennedyLouisiana', 'senatorfeinstein', 'RepMullin', 'RepRubenGallego', 'RepScottPeters', 'joecourtney', 'RepSmucker', 'TomColeOK04', 'CongresswomanLindaSanchez', 'CongressmanDougLamborn', 'RepMikeJohnson', 'SenatorRichardBurr', 'repbrianmast', 'repjimjordan', 'RepMikeTurner', 'DonaldPayneJr', 'SenatorPatrickLeahy', 'RepTomReed', 'CongressmanBoyle', 'SenatorCortezMasto', 'ChelliePingree', 'RepRoKhanna', 'senatormikelee', 'CongressmanHalRogers', 'SenatorMarcoRubio', 'jerrymoran', 'chrisvanhollen', 'RepDelBene', 'CongressmanJimHimes', 'RepRobWittman', 'CongressmanRickAllen', 'jiminhofe', 'RepEspaillat', 'RepDebbieDingell', 'RepBradWenstrup', 'RepKarenBass', 'TXRandy14', 'RepFredUpton', 'SenatorTedCruz', 'RepresentativeMarcyKaptur', 'RepMikeGallagher', 'RepDonYoung', '395759603917487', 'susancollins', 'RepBillJohnson', '118514606128', 'RepRonEstes', 'RepSeanMaloney', 'RepMcKinley', 'SenatorAngusSKingJr', 'senronjohnson', 'repdavidschweikert', 'RepMikeThompson', 'RepMoolenaar', 'RepAndyBiggs', 'RepStephMurphy', 'sanfordbishop', 'RepSarbanes', 'CongressmanGaryPalmer', 'RepSteveWomack', 'RepLeeZeldin', 'RepDanKildee', 'JoeWilson', '81125319109', 'congressmancomer', '96007744606', 'GusBilirakis', '115356957005', 'RepDwightEvans', 'RepPerlmutter', 'RepJackieWalorski', 'CongressmanBradSchneider', 'CongressmanFredKeller', 'aumuaamata', 'CongressmanJodyHice', 'reprichardneal', 'replahood', 'SenatorDurbin', 'RepGrothman', 'RepLouCorrea', 'SenatorWhitehouse', 'RepLaMalfa', 'CongressmanMcHenry', 'RepVirginiaFoxx', 'CongressmanGerryConnolly', 'SenDanSullivan', 'RepAndyBarr', 'repbrianfitzpatrick', 'mdiazbalart', 'SenatorBlunt', 'CongresswomanTitus', 'stevenpalazzo', 'USSenatorLindseyGraham', 'RepDrewFerguson', 'mikecrapo', 'SenatorStabenow', 'DutchRupp', 'lloyddoggett', 'CongressmanEricSwalwell', 'judgecarter', 'RepJimCosta', 'RepAnnaEshoo', 'RepJackyRosen', 'CongressmanRaulRuizMD', 'senatorhirono', 'RepThomasMassie', 'congresswomanbonamici', 'SenLisaMurkowski', 'RepWilson', 'RepNormaTorres', 'RepJohnKatko', 'RepGraceNapolitano', 'JohnBoozman', 'RepHakeemJeffries', 'RepJudyChu', 'RepDaveJoyce', 'MartinHeinrich', '191056827594903', 'reploudermilk', 'CongressmanMattGaetz', 'jefffortenberry', 'RepRickLarsen', 'SenBlumenthal', 'RepAnnWagner', 'michaeltmccaul', 'RepRodneyDavis', 'RichardShelby', 'RepChrisSmith', 'doris.matsui', 'RepRutherfordFL', 'repsaludcarbajal', 'PeterWelch', 'CongressmanAndreCarson', 'NancyPelosi', 'SenDuckworth', 'CongressmanGT', 'congressmanraja', 'CongresswomanNorton', 'senatormenendez', 'JimCooper', 'MaxineWaters', 'SteveDainesMT', 'USCongressmanVicenteGonzalez', 'RepCarolynMaloney', 'CongressmanDarrenSoto', 'senschumer', 'repstaceyplaskett', 'CongresswomanAdams', 'Rep.Billy.Long', 'congressmanbuddycarter', 'SenatorShaheen', 'USRepKathyCastor', 'boblatta', 'CongresswomanSinema', 'RepJennifferGonzalezColon', 'repbettymccollum', 'repyvettedclarke', 'RepCharlieCrist', 'usrepmikedoyle', 'senatortoomey', 'RepJayapal', '326420614138023', 'RepLowenthal', 'SenatorSherrodBrown', 'jerrymcnerney', 'repjasonsmith', 'CongresswomanEBJtx30', 'CongresswomanSheilaJacksonLee', '70063393423', '63158229861', 'RepWebster', '214258646163', 'JackieSpeier', 'kevinbrady', 'senrobportman', 'Rep.BluntRochester', 'RepBrianBabin', 'repraskin', 'reptomemmer', 'repdanbishop', 'repmikequigley', 'MarkRWarner', 'EdJMarkey', 'senatorsanders', 'repohalleran', 'grassley', 'RepRalphNorman', 'RepDWS', 'RepMorganGriffith', 'MarkAmodeiNV2', 'RepJimmyGomez', 'Rep.Grijalva', 'repronkind', 'janschakowsky', 'SenKirstenGillibrand', 'repkenbuck', 'reppeteaguilar', 'RepDavidEPrice', 'SenatorToddYoung', 'CongressmanJimLangevin', 'RepFrenchHill', 'CongresswomanClark', 'SenatorBobCasey', 'Congresswoman.Hartzler', 'derek.kilmer', 'reptrentkelly', 'SenMarkKelly', 'congressmanbobbyrush', 'CongresswomanBarragan', 'RepKayGranger', 'michaelcburgess', 'RepPeterDeFazio', 'SenatorWicker', 'RepMikeGarcia', 'RepAlLawsonJr', 'RepNewhouse', '8037068318'}

# set_of_pol_full_names = {'Brendan F. Boyle', 'Andy Kim', 'Lauren Underwood', 'Thomas P. Tiffany', 'Rand Paul', 'Mike Rogers', 'Salud O. Carbajal', 'Gary C. Peters', 'John Katko', 'Greg Pence', 'Eddie Bernice Johnson', 'Jim Costa', 'Aumua Amata Coleman Radewagen', 'Suzanne Bonamici', 'Tony Gonzales', 'Raja Krishnamoorthi', 'David B. McKinley', 'Stephanie I. Bice', 'Victoria Spartz', 'A. Drew Ferguson IV', 'Mary E. Miller', 'Lucille Roybal-Allard', 'Kirsten E. Gillibrand', 'Jeff Fortenberry', 'Darren Soto', 'John B. Larson', 'Troy Balderson', 'James Comer', 'Ken Buck', 'Russ Fulcher', 'Eric A. "Rick" Crawford', 'Brian Schatz', 'Doug Lamborn', 'Henry C. "Hank" Johnson, Jr.', 'Tom Emmer', 'Sam Graves', 'Alexandria Ocasio-Cortez', 'Richard Burr', 'Patty Murray', 'Ed Perlmutter', 'Charlie Crist', 'Kevin Brady', 'Lisa C. McClain', 'Cori Bush', 'Bill Cassidy', 'Mike Garcia', 'Ben Sasse', 'Tina Smith', 'Robert B. Aderholt', 'Mark DeSaulnier', 'Nicole Malliotakis', 'Al Green', 'Mariannette Miller-Meeks', 'Thomas R. Suozzi', 'Christopher H. Smith', 'Debbie Wasserman Schultz', 'Trey Hollingsworth', 'Mike Levin', 'Troy E. Nehls', 'Zoe Lofgren', 'Debbie Lesko', 'Mo Brooks', 'Matthew M. Rosendale', 'Mark E. Amodei', 'Rick W. Allen', 'Bill Hagerty', 'Donald Norcross', 'Marie Newman', 'Chris Van Hollen', 'Robert J. Wittman', 'Grace Meng', 'Nikema Williams', 'Dean Phillips', 'Pat Fallon', 'Eric Swalwell', 'Earl L. "Buddy" Carter', 'Kurt Schrader', 'Dan Bishop', 'Sherrod Brown', 'Ted Lieu', 'Jason Crow', 'Judy Chu', 'Cathy McMorris Rodgers', 'Anthony Gonzalez', 'Kaiali’i Kahele', 'Cynthia Axne', 'Jody B. Hice', 'Jack Bergman', 'Nancy Mace', 'Kevin Hern', 'Richard Blumenthal', 'Kathy E. Manning', 'David Kustoff', 'Greg Stanton', 'Richard C. Shelby', 'Michael T. McCaul', 'Tim Walberg', 'David N. Cicilline', 'Mark R. Warner', 'Paul Tonko', 'Val Butler Demings', 'Mark E. Green', 'Lois Frankel', 'Steve Daines', 'Tracey Mann', 'Guy Reschenthaler', 'Kat Cammack', 'Roy Blunt', 'André Carson', 'Alexander Mooney', 'Adrian Smith', 'Bob Gibbs', 'Pete Aguilar', 'Richard E. Neal', 'Ann Kirkpatrick', 'Fred Keller', 'Scott H. Peters', 'Andy Barr', 'Mark Kelly', 'Cindy Hyde-Smith', 'Joaquin Castro', 'Joe Wilson', 'Jack Reed', 'Lance Gooden', 'Thomas Massie', 'David Schweikert', 'Bill Johnson', 'John A. Yarmuth', 'Scott Fitzgerald', 'Roger Williams', 'Andy Biggs', 'Tom Malinowski', 'Joni Ernst', 'Angus S. King, Jr.', 'Patrick J. Leahy', 'C. A. Dutch Ruppersberger', 'John R. Moolenaar', 'Virginia Foxx', 'Tom Rice', 'John Thune', 'Barry Moore', 'Devin Nunes', 'Rashida Tlaib', 'Marc A. Veasey', 'Joe Neguse', 'Madison Cawthorn', 'Mike Bost', 'Pramila Jayapal', 'Bob Good', 'Jesús G. "Chuy" García', 'Larry Bucshon', 'Jared Huffman', 'Chris Jacobs', 'Mary Gay Scanlon', 'James E. Risch', 'Nancy Pelosi', 'Gregory W. Meeks', 'John W. Hickenlooper', 'Rick Scott', 'Jay Obernolte', 'Charles J. "Chuck" Fleischmann', 'Katherine M. Clark', 'Lizzie Fletcher', 'Jared F. Golden', 'Derek Kilmer', 'Tim Scott', 'Richard J. Durbin', 'Jim Cooper', 'Ann Wagner', 'Mondaire Jones', 'Michael C. Burgess', 'Cheri Bustos', 'August Pfluger', 'Sean Patrick Maloney', 'Edward J. Markey', 'Bernard Sanders', 'Ron Estes', 'Amy Klobuchar', 'Haley M. Stevens', 'Hakeem S. Jeffries', 'Dan Crenshaw', 'Tim Burchett', 'Tim Ryan', 'Michael K. Simpson', 'Diana DeGette', 'Todd Young', 'Melanie A. Stansbury', 'Lee M. Zeldin', 'Filemon Vela', 'Elissa Slotkin', 'Michael F. Bennet', 'Terri Sewell', 'Tom Cotton', 'Andrew R. Garbarino', 'Andrew S. Clyde', 'Markwayne Mullin', 'John Rose', 'James R. Langevin', 'Josh Harder', 'Burgess Owens', 'Stephen F. Lynch', 'Jake LaTurner', 'Rick Larsen', 'Jon Ossoff', 'Matt Cartwright', 'Andy Harris', 'Blaine Luetkemeyer', 'Michelle Steel', 'Garret Graves', 'Mikie Sherrill', 'Mike Quigley', 'Gregory F. Murphy', 'Richard Hudson', 'Liz Cheney', 'John P. Sarbanes', 'Elizabeth Warren', 'G. K. Butterfield', 'Ami Bera', 'Brad R. Wenstrup', 'James A. Himes', 'Neal P. Dunn', 'Byron Donalds', 'John Kennedy', 'Chellie Pingree', 'Chris Stewart', 'Bill Pascrell, Jr.', 'Brett Guthrie', 'Marsha Blackburn', 'Louie Gohmert', 'Lisa Blunt Rochester', 'Jenniffer González-Colón', 'Ken Calvert', 'Bradley Scott Schneider', 'Dan Sullivan', 'Don Bacon', 'Sean Casten', 'Brian K. Fitzpatrick', 'Kathleen M. Rice', 'Susie Lee', 'Yvette D. Clarke', 'Nydia M. Velázquez', 'Julia Brownley', 'Ayanna Pressley', 'William R. Timmons IV', 'Shelley Moore Capito', 'Mike Lee', 'Jahana Hayes', 'Michael F. Q. San Nicolas', 'Maria Elvira Salazar', 'Brian Babin', 'Chris Pappas', 'Carolyn Bourdeaux', 'Rob Portman', 'Maxine Waters', 'Jaime Herrera Beutler', 'Dianne Feinstein', 'Tom Cole', 'Anthony Brown', 'Steve Chabot', 'Ben Ray Luján', 'Thom Tillis', 'Mike Johnson', 'Karen Bass', 'Thomas R. Carper', 'Beth Van Duyne', 'Barry Loudermilk', 'Gus M. Bilirakis', 'Martin Heinrich', 'Donald S. Beyer, Jr.', 'Jennifer Wexton', 'Pete Sessions', 'Teresa Leger Fernandez', 'Gerald E. Connolly', 'Mike Kelly', 'Marco Rubio', 'Elaine G. Luria', 'Ted Budd', 'Rodney Davis', 'Adam Kinzinger', 'Yvette Herrell', 'Doug LaMalfa', 'Lucy McBath', 'Adam Smith', 'Lisa Murkowski', 'H. Morgan Griffith', 'Brenda L. Lawrence', 'Patrick T. McHenry', 'Jason Smith', 'Michael Guest', 'Ron Kind', 'Kyrsten Sinema', 'Jake Auchincloss', 'Bill Posey', 'Ralph Norman', 'Robert C. "Bobby" Scott', 'Michael Cloud', 'Jackie Speier', 'Margaret Wood Hassan', 'Tommy Tuberville', 'Gregorio Kilili Camacho Sablan', 'Dwight Evans', 'Ed Case', 'Josh Gottheimer', 'Lori Trahan', 'Lloyd Smucker', 'Raúl M. Grijalva', 'Jacky Rosen', 'Ron Wyden', 'Jimmy Gomez', 'David E. Price', 'J. Hill', 'Joe Manchin, III', 'Gwen Moore', 'Tom O’Halleran', 'Bobby L. Rush', 'Catherine Cortez Masto', 'Kim Schrier', 'Roger F. Wicker', 'Joseph D. Morelle', 'Dusty Johnson', 'Harold Rogers', 'Peter A. DeFazio', 'Trent Kelly', 'Christopher A. Coons', 'Lauren Boebert', 'Maria Cantwell', 'W. Gregory Steube', 'Patrick J. Toomey', 'Donald M. Payne, Jr.', 'Benjamin L. Cardin', 'Henry Cuellar', 'Steny H. Hoyer', 'Jim Banks', 'Josh Hawley', 'Carol D. Miller', 'Kathy Castor', 'Frederica S. Wilson', 'Robin L. Kelly', 'Tammy Baldwin', 'Paul A. Gosar', 'Elise M. Stefanik', 'James E. Clyburn', 'Robert P. Casey, Jr.', 'Daniel Webster', 'Cory A. Booker', 'Debbie Stabenow', 'Matt Gaetz', 'Steven Horsford', 'Ben Cline', 'James R. Baird', 'David G. Valadao', 'Lindsey Graham', 'Stephanie N. Murphy', 'Van Taylor', 'Vicente Gonzalez', 'Claudia Tenney', 'Don Young', 'David Rouzer', 'Peter Meijer', 'Nanette Diaz Barragán', 'Randy K. Weber, Sr.', 'Austin Scott', 'Tim Kaine', 'Tony Cárdenas', 'Joe Courtney', 'Tom Reed', 'Kay Granger', 'Ron Johnson', 'Warren Davidson', 'John H. Rutherford', 'Albio Sires', 'Ashley Hinson', 'Raphael G. Warnock', 'Fred Upton', 'John Barrasso', 'Ronny Jackson', 'Charles E. Schumer', 'Troy A. Carter', 'Seth Moulton', 'Tom McClintock', 'J. Luis Correa', 'Angie Craig', 'Frank D. Lucas', 'Roger Marshall', 'Mitch McConnell', 'Jackie Walorski', 'Joyce Beatty', 'Lloyd Doggett', 'David J. Trone', 'Brad Sherman', 'John R. Carter', 'Jamaal Bowman', 'Steve Womack', 'Jerry L. Carl', 'Michelle Fischbach', 'Mark Pocan', 'Glenn Grothman', 'Raul Ruiz', 'Sylvia R. Garcia', 'Jim Jordan', 'Mitt Romney', 'Deb Fischer', 'Peter Welch', 'Darrell Issa', 'James P. McGovern', 'Rosa L. DeLauro', 'Janice D. Schakowsky', 'Dina Titus', 'Sharice Davids', 'Mario Diaz-Balart', 'Blake D. Moore', 'Daniel T. Kildee', 'Jerry McNerney', 'Ritchie Torres', 'Adriano Espaillat', 'Andy Levin', 'Betty McCollum', 'Frank Pallone, Jr.', 'Randy Feenstra', 'John R. Curtis', 'Ann Kuster', 'Jim Hagedorn', 'Robert Menendez', 'Cynthia M. Lummis', 'Bennie G. Thompson', 'Jon Tester', 'Marcy Kaptur', 'Alma S. Adams', 'Suzan K. DelBene', 'Brian J. Mast', 'Jodey C. Arrington', 'James M. Inhofe', 'Conor Lamb', 'Madeleine Dean', 'Marjorie Taylor Greene', 'Steve Scalise', 'Sheila Jackson Lee', 'Daniel Meuser', 'Sanford D. Bishop, Jr.', 'Jeanne Shaheen', 'Ruben Gallego', 'A. Donald McEachin', 'Bill Huizenga', 'Doris O. Matsui', 'Bill Foster', 'Gary J. Palmer', 'Stacey E. Plaskett', 'Darin LaHood', 'Abigail Davis Spanberger', 'John Garamendi', 'Adam B. Schiff', 'David P. Joyce', 'Al Lawson, Jr.', 'Chrissy Houlahan', 'Mike Crapo', 'Glenn Thompson', 'Frank J. Mrvan', 'Jamie Raskin', 'Dan Newhouse', 'John Joyce', 'Susan Wild', 'Carlos A. Gimenez', 'Alex Padilla', 'Eleanor Holmes Norton', 'Alan S. Lowenthal', 'John Hoeven', 'Susan M. Collins', 'Mike Thompson', 'Pete Stauber', 'John Cornyn', 'Scott Perry', 'David Scott', 'Robert E. Latta', 'Jeff Duncan', 'Michael Waltz', 'Jimmy Panetta', 'Jefferson Van Drew', 'Veronica Escobar', 'Ilhan Omar', 'Anna G. Eshoo', 'Scott DesJarlais', 'Christopher Murphy', 'Chuck Grassley', 'William R. Keating', 'Debbie Dingell', 'Vern Buchanan', 'Chip Roy', 'Kelly Armstrong', 'Kevin McCarthy', 'Ro Khanna', 'Cliff Bentz', 'Diana Harshbarger', 'Brian Higgins', 'Norma J. Torres', 'Jerry Moran', 'Bryan Steil', 'Mike Braun', 'Carolyn B. Maloney', 'Earl Blumenauer', 'Deborah K. Ross', 'Mazie K. Hirono', 'Young Kim', 'Sara Jacobs', 'Barbara Lee', 'Tammy Duckworth', 'Julia Letlow', 'John Boozman', 'Bruce Westerman', 'Grace F. Napolitano', 'Linda T. Sánchez', 'Mark Takano', 'Katie Porter', 'Theodore E. Deutch', 'Mike Gallagher', 'Michael R. Turner', 'Ted Cruz', 'Sheldon Whitehouse', 'Bonnie Watson Coleman', 'James Lankford', 'Colin Z. Allred', 'Kevin Cramer', 'C. Scott Franklin', 'Steven M. Palazzo', 'Antonio Delgado', 'Jeff Merkley', 'Emanuel Cleaver', 'Danny K. Davis', 'Kweisi Mfume', 'Juan Vargas', 'Marilyn Strickland', 'Steve Cohen', 'Clay Higgins', 'Vicky Hartzler', 'Michael F. Doyle', 'Billy Long', 'Jerrold Nadler', 'Mike Rounds'}

# white_house = {'Joe Biden', 'Kamala Harris', 'Barack Obama', 'Donald J. Trump', 'Mike Pence'}

# combined = white_house.union(set_of_pol_full_names)

# #To check for substring
# data.loc[data['page_name'].str.contains('Congressman')]

# data.loc[data['page_name'].str.contains('Congresswoman')]

# data.loc[data['page_name'].str.contains('Senator')]
# #Results with this

# data.loc[data['page_name'].str.contains('Governor')]
# #Results with this

# #pol_fbpage_names = get_pol_fbpage_names()

# df_by_pol = data.loc[data['page_name'].isin(combined)]

# df_by_pol.groupby('page_name').count()
